# %%
import pandas as pd

#First out imports
#Lets import some stuff!

#Numpy
import numpy as np

#Cartopy for mapping
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter


#Matplotlib for plotting
import matplotlib.pyplot as plt

#Siphon for finding data
from siphon.catalog import TDSCatalog
from siphon.ncss import NCSS

#date tools
from datetime import datetime, timedelta
from netCDF4 import num2date

#os tools
import os

# %matplotlib inline

# %%
asos_data = pd.read_csv('../data/ak_asos.csv')

# %%
asos_gb = asos_data.groupby('station')

# %%
asos_data['date'] = pd.to_datetime(asos_data['valid'])

# %%
start_date = '2018-05-12'
end_date = '2018-05-14'
mask = (asos_data['date'] > start_date) & (asos_data['date'] <= end_date)

# %%
asos_data_may = asos_data[mask]

# %%
asos_data_may
# Out:
#        station             valid       lon      lat   tmpf   dwpf    relh  \
# 410976    PAFS  2018-05-12 00:01 -154.3600  63.0200  46.00  32.00   57.87
# 410977    PAEH  2018-05-12 00:02 -162.0628  58.6464  37.40  35.60   93.14
# 410978    PADM  2018-05-12 00:02 -162.0261  61.8643  45.00  37.00   73.37
# 410979    PAMO  2018-05-12 00:02 -163.6819  62.0953  48.00  34.00   58.16
# 410980    PASM  2018-05-12 00:02 -163.3018  62.0608  45.00  37.00   73.37
# 410981    PASH  2018-05-12 00:02 -166.0893  66.2496  33.80  32.00   93.03
# 410982    PAVD  2018-05-12 00:03 -146.2480  61.1340  44.60  39.20   81.20
# 410983    PAGA  2018-05-12 00:05 -156.9374  64.7362      M      M       M
# 410984    PAMD  2018-05-12 00:05 -146.3380  59.4320      M      M       M
# 410985    PAVL  2018-05-12 00:05 -164.5483  67.7317      M      M       M
# 410986    PAOM  2018-05-12 00:05 -165.4452  64.5122      M      M       M
# 410987    PASX  2018-05-12 00:05 -151.0342  60.4758      M      M       M
# ...

# %%
asos_data_may.to_csv('/Users/scollis/funded_projects/precip_change/data/asos_data_may.csv')

# %%
start_date = '2018-07-07'
end_date = '2018-07-09'
mask = (asos_data['date'] > start_date) & (asos_data['date'] <= end_date)
asos_data_july = asos_data[mask]
asos_data_july.to_csv('/Users/scollis/funded_projects/precip_change/data/asos_data_july.csv')
